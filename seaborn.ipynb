# %% [markdown]
# # Seaboron
# pyhton library for highlevel data visulization
#
# # Scatterplot
# 1. relplot (figure level)
# 2. scatterplot (axes level)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Plot a scatter Plot between total_bill and tip

# %% [markdown]
# # Hue parameter

# %%
#plot here
sns.relplot(x='total_bill', y='tip', data=data)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=data)
plt.show()

# %% [markdown]
# # Style parameter

# %%
#plot here
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', data=data)
plt.show()

# %% [markdown]
# # Size parameter

# %%
#plot here
sns.relplot(x='total_bill', y='tip',hue='smoker', style='sex', size='size', sizes=(15,200), data=data)
plt.show()

# %% [markdown]
# # Using scatterplot function

# %%
#plot here
sns.relplot(x='total_bill', y='tip',hue='smoker', data=data)
plt.show()

# %% [markdown]
# # Plotting with Categorical Data
# catplot (figure level function)
#
# # 1. Categorical Scatterplots
# 1. Stripplot
# 2. Swarmplot
#
# # 2. Categorical distribution plots
# 1. Boxplot
# 2. Violinplot
#
# # 3. Categorical estimate plots
# 1. pointplot
# 2. barplots
# 3. Countplot
#
# # 4. Categorical categorical plots
# 1. heatmap
# 2. clusterplots
#
# # 5. Plotting side by side graph using Facetgrid

# %% [markdown]
# # Categorical Scatterplot

# %%
 # x-axis--> Categorical data
# y-axis --> Numerical Data

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='tip', kind='strip', data=data)
plt.show()
#jitter -- noice

# %%
sns.catplot(x='day', y='tip', kind='strip',jitter=0, data=data)
plt.show()

# %%
sns.catplot(x='day', y='tip', kind='swarm', data=data)
plt.show()

#represents distribution of data, when multiple value occupying same value
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', kind='swarm', hue='sex', data=data)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='day', y='tip',  data=data)
plt.show()

# %% [markdown]
# # Box plot

# %%
# univariate analysis
sns.boxplot(data['tip'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# multivariate analysis
sns.catplot(x='day', y='total_bill', kind='box', data=data)
plt.show()

# %%
sns.catplot(x='day', y='total_bill', kind='box',hue='sex', data=data)
plt.show()

# %% [markdown]
# # Violinplots

# %%
sns.violinplot(data['total_bill'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='day', y='total_bill', kind='violin',  data=data)
plt.show()

# %%
sns.catplot(x='day', y='total_bill', kind='violin', hue='sex', split=True,  data=data)
plt.show()

# %% [markdown]
# # Barplot and Countplot

# %%
sns.catplot(x='smoker', y='total_bill', kind='bar', data=data)
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', kind='bar',hue='sex', data=data)
plt.show()

# %%
sns.catplot(x='smoker', y='total_bill', kind='bar',hue='sex', estimator=np.median, data=data)
plt.show()

# %%
sns.catplot(x='sex', kind='count', data=data)
plt.show()

# %%
sns.catplot(x='sex', kind='count', hue='smoker', data=data)
plt.show()

# %% [markdown]
# # Heatmap

# %%
flight=sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
x=flight.pivot_table(index='year', columns='month', values='passengers', aggfunc='sum')

# %%
sns.heatmap(x)
plt.show()

# %%
sns.heatmap(x, cbar=False)
plt.show()

# %%
 sns.heatmap(x, cbar=False, linewidths=0.5)  #distance b/w tw adjacent cells can be increase
plt.show()

# %%
 sns.heatmap(x, cbar=False, linewidths=0.5, annot=True, fmt='d')  
plt.show()

# %%
 sns.heatmap(x, cbar=False, linewidths=0.5, annot=True, fmt='d', cmap='winter' )
plt.show()

# %% [markdown]
# # Clustermap

# %%
#type of heatmap but is clustered, cluster rows and columns together on the basis of similarity
#similar rows come together and vice versa

# %%
 sns.clustermap(x)
plt.show()

# %%
 sns.clustermap(x, metric='correlation')
plt.show()

# %%
 sns.clustermap(x,z_score=0, annot=True, metric='correlation')
plt.show()

# %%
 sns.clustermap(x,z_score=0, annot=True, row_cluster=False, metric='correlation')
plt.show()  #now just on the basis of columns not rows

# %%
 sns.clustermap(x,z_score=0, annot=True, col_cluster=False, metric='correlation')
plt.show()  #now just on the basis of rows not columns

# %% [markdown]
# # Jointplot

# %%
# multipanel figure that shows both bivariate and univariate on separate axes
#used in 4-manner
#1. scatterplots
#2. hexbin plot
#3. kdeplots
#4. regplot

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 1. Scatterplot
sns.jointplot(x='total_bill', y='tip', data=data)
plt.show() 
#on x-axis histogram of total bill
#on y-axis histrogram of tip

# %%
# 2. Hexbin plot  #2-D histogram plot
sns.jointplot(x='total_bill', y='tip', kind='hex', data=data)
plt.show()

# %%
# 2. Kde plot  #2-D pdf
sns.jointplot(x='total_bill', y='tip', kind='kde', data=data)
plt.show()

# %%
# 2. Regplot --regression  plot, best fit line used for prediction
sns.jointplot(x='total_bill', y='tip', kind='reg', data=data)
plt.show()

# %% [markdown]
# # Pairplot

# %%
#used to plot  multpiple airwise bivariate distribution in a dataset
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris) #diagnols are histogram others are scatterplots
plt.show()

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# # Displots

# %%
# used to do univariate analysis on conto=inoous/numerical data
# combines 3-things in ine graph
# 1.histogram
# 2. kernel density estimation(PDF)
# 3. Rugplot

# %%
titanic= sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['age'].fillna(titanic['age'].mean(), inplace=True)

# %% [markdown]
# # plotting displot

# %%
sns.distplot(titanic['age']) #pdf+hist
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#plotting only histogram
sns.distplot(titanic['age'], kde=False)
plt.show()

# %%
sns.distplot(titanic['age'],bins=10, kde=False)
plt.show()

# %%
#plotting only Kde
sns.distplot(titanic['age'], hist=False)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#plotting only rugplot --> on x-axis, side by side
sns.distplot(titanic['age'], hist=False, kde=False, rug=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
#HOW TO USE DISPLOT
sns.distplot(titanic[titanic['survived']==1]['age'])
sns.distplot(titanic[titanic['survived']==0]['age'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
